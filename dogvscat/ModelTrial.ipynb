# %%
import numpy as np
from keras.models import load_model
from keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\Said\anaconda3\envs\tf310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = load_model("dog_vs_cat_model.keras")
img_path = "Trial.jpg"
img = image.load_img(img_path, target_size=(64, 64))
img_array = image.img_to_array(img)
img_array = img_array / 255.0  
img_array = np.expand_dims(img_array, axis=0)

# %%
prediction = model.predict(img_array)
# Out:
# 1/1 [==============================] - 0s 63ms/step

# %%
if prediction[0] < 0.5:
    print("Cat (%.2f%%)" % (100 - prediction[0]*100))
else:
    print("Dog (%.2f%%)" % (prediction[0]*100))
# Out:
# Dog (57.18%)

# %%
plt.imshow(img)
plt.title("Prediction: " + ("Dog" if prediction[0] >= 0.5 else "Cat"))
plt.axis('off')
plt.show()
